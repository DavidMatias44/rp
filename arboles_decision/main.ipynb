# %%
import pandas as pd
from sklearn import tree 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./glass.csv')
df
# Out:
#       ID       RI   NA2O   MGO  AL2O3   SIO2   K2O   CAO   BAO  FE2O3  TYPE
# 0      1  1.52101  13.64  4.49   1.10  71.78  0.06  8.75  0.00    0.0     1
# 1      2  1.51761  13.89  3.60   1.36  72.73  0.48  7.83  0.00    0.0     1
# 2      3  1.51618  13.53  3.55   1.54  72.99  0.39  7.78  0.00    0.0     1
# 3      4  1.51766  13.21  3.69   1.29  72.61  0.57  8.22  0.00    0.0     1
# 4      5  1.51742  13.27  3.62   1.24  73.08  0.55  8.07  0.00    0.0     1
# ..   ...      ...    ...   ...    ...    ...   ...   ...   ...    ...   ...
# 209  210  1.51623  14.14  0.00   2.88  72.61  0.08  9.18  1.06    0.0     7
# 210  211  1.51685  14.92  0.00   1.99  73.06  0.00  8.40  1.59    0.0     7
# 211  212  1.52065  14.36  0.00   2.02  73.42  0.00  8.44  1.64    0.0     7
# 212  213  1.51651  14.38  0.00   1.94  73.61  0.00  8.48  1.57    0.0     7
# 213  214  1.51711  14.23  0.00   2.08  73.36  0.00  8.62  1.67    0.0     7
#
# [214 rows x 11 columns]

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       ID       RI   NA2O   MGO  AL2O3   SIO2   K2O   CAO   BAO  FE2O3  TYPE
# 0      1  1.52101  13.64  4.49   1.10  71.78  0.06  8.75  0.00    0.0     1
# 1      2  1.51761  13.89  3.60   1.36  72.73  0.48  7.83  0.00    0.0     1
# 2      3  1.51618  13.53  3.55   1.54  72.99  0.39  7.78  0.00    0.0     1
# 3      4  1.51766  13.21  3.69   1.29  72.61  0.57  8.22  0.00    0.0     1
# 4      5  1.51742  13.27  3.62   1.24  73.08  0.55  8.07  0.00    0.0     1
# ..   ...      ...    ...   ...    ...    ...   ...   ...   ...    ...   ...
# 209  210  1.51623  14.14  0.00   2.88  72.61  0.08  9.18  1.06    0.0     7
# 210  211  1.51685  14.92  0.00   1.99  73.06  0.00  8.40  1.59    0.0     7
# 211  212  1.52065  14.36  0.00   2.02  73.42  0.00  8.44  1.64    0.0     7
# 212  213  1.51651  14.38  0.00   1.94  73.61  0.00  8.48  1.57    0.0     7
# 213  214  1.51711  14.23  0.00   2.08  73.36  0.00  8.62  1.67    0.0     7
#
# [214 rows x 11 columns]>

# %%
X = df.drop(['ID', 'TYPE'], axis=1)
X
# Out:
#           RI   NA2O   MGO  AL2O3   SIO2   K2O   CAO   BAO  FE2O3
# 0    1.52101  13.64  4.49   1.10  71.78  0.06  8.75  0.00    0.0
# 1    1.51761  13.89  3.60   1.36  72.73  0.48  7.83  0.00    0.0
# 2    1.51618  13.53  3.55   1.54  72.99  0.39  7.78  0.00    0.0
# 3    1.51766  13.21  3.69   1.29  72.61  0.57  8.22  0.00    0.0
# 4    1.51742  13.27  3.62   1.24  73.08  0.55  8.07  0.00    0.0
# ..       ...    ...   ...    ...    ...   ...   ...   ...    ...
# 209  1.51623  14.14  0.00   2.88  72.61  0.08  9.18  1.06    0.0
# 210  1.51685  14.92  0.00   1.99  73.06  0.00  8.40  1.59    0.0
# 211  1.52065  14.36  0.00   2.02  73.42  0.00  8.44  1.64    0.0
# 212  1.51651  14.38  0.00   1.94  73.61  0.00  8.48  1.57    0.0
# 213  1.51711  14.23  0.00   2.08  73.36  0.00  8.62  1.67    0.0
#
# [214 rows x 9 columns]

# %%
y = df['TYPE']
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 209    7
# 210    7
# 211    7
# 212    7
# 213    7
# Name: TYPE, Length: 214, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=23)

# %%
clf = tree.DecisionTreeClassifier(random_state=23, max_depth=6)
clf = clf.fit(X_train, y_train)

# %%
plt.figure(figsize=(40, 25))
tree.plot_tree(
    clf,
    feature_names=X.columns,
    class_names=y.astype(str).unique(),
    filled=True,
    rounded=True,
    fontsize=10
)
# Out:
# [Text(0.6801948051948052, 0.9285714285714286, 'BAO <= 0.335\ngini = 0.745\nsamples = 171\nvalue = [57, 57, 14, 12, 7, 24]\nclass = 1'),
#  Text(0.4642857142857143, 0.7857142857142857, 'AL2O3 <= 1.42\ngini = 0.692\nsamples = 147\nvalue = [56.0, 56.0, 14.0, 11.0, 7.0, 3.0]\nclass = 1'),
#  Text(0.5722402597402598, 0.8571428571428572, 'True  '),
#  Text(0.2987012987012987, 0.6428571428571429, 'CAO <= 10.425\ngini = 0.594\nsamples = 90\nvalue = [51, 24, 10, 1, 2, 2]\nclass = 1'),
#  Text(0.2077922077922078, 0.5, 'FE2O3 <= 0.115\ngini = 0.56\nsamples = 83\nvalue = [51, 18, 10, 0, 2, 2]\nclass = 1'),
#  Text(0.1038961038961039, 0.35714285714285715, 'RI <= 1.517\ngini = 0.474\nsamples = 61\nvalue = [43, 6, 8, 0, 2, 2]\nclass = 1'),
#  Text(0.05194805194805195, 0.21428571428571427, 'AL2O3 <= 1.215\ngini = 0.519\nsamples = 9\nvalue = [1, 0, 6, 0, 1, 1]\nclass = 3'),
#  Text(0.025974025974025976, 0.07142857142857142, 'gini = 0.667\nsamples = 3\nvalue = [1, 0, 0, 0, 1, 1]\nclass = 1'),
#  Text(0.07792207792207792, 0.07142857142857142, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]\nclass = 3'),
#  Text(0.15584415584415584, 0.21428571428571427, 'MGO <= 3.875\ngini = 0.332\nsamples = 52\nvalue = [42, 6, 2, 0, 1, 1]\nclass = 1'),
#  Text(0.12987012987012986, 0.07142857142857142, 'gini = 0.234\nsamples = 47\nvalue = [41, 2, 2, 0, 1, 1]\nclass = 1'),
#  Text(0.18181818181818182, 0.07142857142857142, 'gini = 0.32\nsamples = 5\nvalue = [1, 4, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.3116883116883117, 0.35714285714285715, 'RI <= 1.519\ngini = 0.562\nsamples = 22\nvalue = [8, 12, 2, 0, 0, 0]\nclass = 2'),
#  Text(0.2597402597402597, 0.21428571428571427, 'RI <= 1.518\ngini = 0.415\nsamples = 17\nvalue = [5, 12, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.23376623376623376, 0.07142857142857142, 'gini = 0.469\nsamples = 8\nvalue = [5, 3, 0, 0, 0, 0]\nclass = 1'),
#  Text(0.2857142857142857, 0.07142857142857142, 'gini = 0.0\nsamples = 9\nvalue = [0, 9, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.36363636363636365, 0.21428571428571427, 'FE2O3 <= 0.205\ngini = 0.48\nsamples = 5\nvalue = [3, 0, 2, 0, 0, 0]\nclass = 1'),
#  Text(0.33766233766233766, 0.07142857142857142, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0, 0]\nclass = 1'),
#  Text(0.38961038961038963, 0.07142857142857142, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]\nclass = 3'),
#  Text(0.38961038961038963, 0.5, 'AL2O3 <= 1.38\ngini = 0.245\nsamples = 7\nvalue = [0, 6, 0, 1, 0, 0]\nclass = 2'),
#  Text(0.36363636363636365, 0.35714285714285715, 'gini = 0.0\nsamples = 6\nvalue = [0, 6, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.4155844155844156, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 5'),
#  Text(0.6298701298701299, 0.6428571428571429, 'MGO <= 2.26\ngini = 0.633\nsamples = 57\nvalue = [5, 32, 4, 10, 5, 1]\nclass = 2'),
#  Text(0.4935064935064935, 0.5, 'NA2O <= 13.495\ngini = 0.599\nsamples = 18\nvalue = [0, 2, 0, 10, 5, 1]\nclass = 5'),
#  Text(0.4675324675324675, 0.35714285714285715, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]\nclass = 5'),
#  Text(0.5194805194805194, 0.35714285714285715, 'RI <= 1.52\ngini = 0.531\nsamples = 8\nvalue = [0, 2, 0, 0, 5, 1]\nclass = 6'),
#  Text(0.4935064935064935, 0.21428571428571427, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]\nclass = 6'),
#  Text(0.5454545454545454, 0.21428571428571427, 'MGO <= 2.145\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 0, 0, 0, 1]\nclass = 2'),
#  Text(0.5194805194805194, 0.07142857142857142, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.5714285714285714, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]\nclass = 7'),
#  Text(0.7662337662337663, 0.5, 'CAO <= 8.325\ngini = 0.381\nsamples = 39\nvalue = [5, 30, 4, 0, 0, 0]\nclass = 2'),
#  Text(0.7012987012987013, 0.35714285714285715, 'FE2O3 <= 0.225\ngini = 0.198\nsamples = 27\nvalue = [3, 24, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.6493506493506493, 0.21428571428571427, 'CAO <= 7.83\ngini = 0.083\nsamples = 23\nvalue = [1, 22, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.6233766233766234, 0.07142857142857142, 'gini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0, 0, 0]\nclass = 1'),
#  Text(0.6753246753246753, 0.07142857142857142, 'gini = 0.0\nsamples = 21\nvalue = [0, 21, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.7532467532467533, 0.21428571428571427, 'NA2O <= 12.82\ngini = 0.5\nsamples = 4\nvalue = [2, 2, 0, 0, 0, 0]\nclass = 1'),
#  Text(0.7272727272727273, 0.07142857142857142, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0]\nclass = 1'),
#  Text(0.7792207792207793, 0.07142857142857142, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.8311688311688312, 0.35714285714285715, 'MGO <= 3.11\ngini = 0.611\nsamples = 12\nvalue = [2, 6, 4, 0, 0, 0]\nclass = 2'),
#  Text(0.8051948051948052, 0.21428571428571427, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.8571428571428571, 0.21428571428571427, 'RI <= 1.518\ngini = 0.625\nsamples = 8\nvalue = [2, 2, 4, 0, 0, 0]\nclass = 3'),
#  Text(0.8311688311688312, 0.07142857142857142, 'gini = 0.444\nsamples = 6\nvalue = [2, 0, 4, 0, 0, 0]\nclass = 3'),
#  Text(0.8831168831168831, 0.07142857142857142, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.8961038961038961, 0.7857142857142857, 'SIO2 <= 70.16\ngini = 0.229\nsamples = 24\nvalue = [1, 1, 0, 1, 0, 21]\nclass = 7'),
#  Text(0.7881493506493507, 0.8571428571428572, '  False'),
#  Text(0.8441558441558441, 0.6428571428571429, 'RI <= 1.523\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]\nclass = 2'),
#  Text(0.8181818181818182, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 5'),
#  Text(0.8701298701298701, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.948051948051948, 0.6428571428571429, 'MGO <= 3.42\ngini = 0.087\nsamples = 22\nvalue = [1, 0, 0, 0, 0, 21]\nclass = 7'),
#  Text(0.922077922077922, 0.5, 'gini = 0.0\nsamples = 21\nvalue = [0, 0, 0, 0, 0, 21]\nclass = 7'),
#  Text(0.974025974025974, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]\nclass = 1')]

# %%
y_pred = clf.predict(X_test)

# %%
print(f"Error: {1 - accuracy_score(y_test, y_pred)}")
# Out:
# Error: 0.32558139534883723
