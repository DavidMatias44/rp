# %%
import pandas as pd
from sklearn import tree 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %%
df = pd.read_csv('./glass.csv')
df
# Out:
#       ID       RI   NA2O   MGO  AL2O3   SIO2   K2O   CAO   BAO  FE2O3  TYPE
# 0      1  1.52101  13.64  4.49   1.10  71.78  0.06  8.75  0.00    0.0     1
# 1      2  1.51761  13.89  3.60   1.36  72.73  0.48  7.83  0.00    0.0     1
# 2      3  1.51618  13.53  3.55   1.54  72.99  0.39  7.78  0.00    0.0     1
# 3      4  1.51766  13.21  3.69   1.29  72.61  0.57  8.22  0.00    0.0     1
# 4      5  1.51742  13.27  3.62   1.24  73.08  0.55  8.07  0.00    0.0     1
# ..   ...      ...    ...   ...    ...    ...   ...   ...   ...    ...   ...
# 209  210  1.51623  14.14  0.00   2.88  72.61  0.08  9.18  1.06    0.0     7
# 210  211  1.51685  14.92  0.00   1.99  73.06  0.00  8.40  1.59    0.0     7
# 211  212  1.52065  14.36  0.00   2.02  73.42  0.00  8.44  1.64    0.0     7
# 212  213  1.51651  14.38  0.00   1.94  73.61  0.00  8.48  1.57    0.0     7
# 213  214  1.51711  14.23  0.00   2.08  73.36  0.00  8.62  1.67    0.0     7
#
# [214 rows x 11 columns]

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       ID       RI   NA2O   MGO  AL2O3   SIO2   K2O   CAO   BAO  FE2O3  TYPE
# 0      1  1.52101  13.64  4.49   1.10  71.78  0.06  8.75  0.00    0.0     1
# 1      2  1.51761  13.89  3.60   1.36  72.73  0.48  7.83  0.00    0.0     1
# 2      3  1.51618  13.53  3.55   1.54  72.99  0.39  7.78  0.00    0.0     1
# 3      4  1.51766  13.21  3.69   1.29  72.61  0.57  8.22  0.00    0.0     1
# 4      5  1.51742  13.27  3.62   1.24  73.08  0.55  8.07  0.00    0.0     1
# ..   ...      ...    ...   ...    ...    ...   ...   ...   ...    ...   ...
# 209  210  1.51623  14.14  0.00   2.88  72.61  0.08  9.18  1.06    0.0     7
# 210  211  1.51685  14.92  0.00   1.99  73.06  0.00  8.40  1.59    0.0     7
# 211  212  1.52065  14.36  0.00   2.02  73.42  0.00  8.44  1.64    0.0     7
# 212  213  1.51651  14.38  0.00   1.94  73.61  0.00  8.48  1.57    0.0     7
# 213  214  1.51711  14.23  0.00   2.08  73.36  0.00  8.62  1.67    0.0     7
#
# [214 rows x 11 columns]>

# %%
X = df.drop(['ID', 'TYPE'], axis=1)
X
# Out:
#           RI   NA2O   MGO  AL2O3   SIO2   K2O   CAO   BAO  FE2O3
# 0    1.52101  13.64  4.49   1.10  71.78  0.06  8.75  0.00    0.0
# 1    1.51761  13.89  3.60   1.36  72.73  0.48  7.83  0.00    0.0
# 2    1.51618  13.53  3.55   1.54  72.99  0.39  7.78  0.00    0.0
# 3    1.51766  13.21  3.69   1.29  72.61  0.57  8.22  0.00    0.0
# 4    1.51742  13.27  3.62   1.24  73.08  0.55  8.07  0.00    0.0
# ..       ...    ...   ...    ...    ...   ...   ...   ...    ...
# 209  1.51623  14.14  0.00   2.88  72.61  0.08  9.18  1.06    0.0
# 210  1.51685  14.92  0.00   1.99  73.06  0.00  8.40  1.59    0.0
# 211  1.52065  14.36  0.00   2.02  73.42  0.00  8.44  1.64    0.0
# 212  1.51651  14.38  0.00   1.94  73.61  0.00  8.48  1.57    0.0
# 213  1.51711  14.23  0.00   2.08  73.36  0.00  8.62  1.67    0.0
#
# [214 rows x 9 columns]

# %%
y = df['TYPE']
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 209    7
# 210    7
# 211    7
# 212    7
# 213    7
# Name: TYPE, Length: 214, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)

# %%
tree.plot_tree(clf)
# Out:
# [Text(0.5108695652173914, 0.9583333333333334, 'x[7] <= 0.335\ngini = 0.739\nsamples = 171\nvalue = [57, 59, 14, 11, 7, 23]'),
#  Text(0.29347826086956524, 0.875, 'x[2] <= 2.56\ngini = 0.69\nsamples = 149\nvalue = [56, 58, 14, 11, 7, 3]'),
#  Text(0.40217391304347827, 0.9166666666666667, 'True  '),
#  Text(0.09782608695652174, 0.7916666666666666, 'x[5] <= 0.03\ngini = 0.696\nsamples = 30\nvalue = [0, 10, 0, 11, 7, 2]'),
#  Text(0.043478260869565216, 0.7083333333333334, 'x[1] <= 13.755\ngini = 0.346\nsamples = 9\nvalue = [0, 2, 0, 0, 7, 0]'),
#  Text(0.021739130434782608, 0.625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.06521739130434782, 0.625, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 7, 0]'),
#  Text(0.15217391304347827, 0.7083333333333334, 'x[1] <= 13.495\ngini = 0.571\nsamples = 21\nvalue = [0, 8, 0, 11, 0, 2]'),
#  Text(0.10869565217391304, 0.625, 'x[0] <= 1.524\ngini = 0.418\nsamples = 15\nvalue = [0, 3, 0, 11, 0, 1]'),
#  Text(0.08695652173913043, 0.5416666666666666, 'x[4] <= 74.53\ngini = 0.153\nsamples = 12\nvalue = [0, 0, 0, 11, 0, 1]'),
#  Text(0.06521739130434782, 0.4583333333333333, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 0, 11, 0, 0]'),
#  Text(0.10869565217391304, 0.4583333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.13043478260869565, 0.5416666666666666, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0, 0]'),
#  Text(0.1956521739130435, 0.625, 'x[5] <= 0.645\ngini = 0.278\nsamples = 6\nvalue = [0, 5, 0, 0, 0, 1]'),
#  Text(0.17391304347826086, 0.5416666666666666, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0, 0, 0]'),
#  Text(0.21739130434782608, 0.5416666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.4891304347826087, 0.7916666666666666, 'x[6] <= 8.325\ngini = 0.602\nsamples = 119\nvalue = [56, 48, 14, 0, 0, 1]'),
#  Text(0.33695652173913043, 0.7083333333333334, 'x[3] <= 1.405\ngini = 0.392\nsamples = 43\nvalue = [10, 32, 1, 0, 0, 0]'),
#  Text(0.2826086956521739, 0.625, 'x[2] <= 3.76\ngini = 0.56\nsamples = 15\nvalue = [7, 7, 1, 0, 0, 0]'),
#  Text(0.2608695652173913, 0.5416666666666666, 'x[2] <= 3.565\ngini = 0.46\nsamples = 10\nvalue = [7, 2, 1, 0, 0, 0]'),
#  Text(0.2391304347826087, 0.4583333333333333, 'x[2] <= 3.475\ngini = 0.625\nsamples = 4\nvalue = [1, 2, 1, 0, 0, 0]'),
#  Text(0.21739130434782608, 0.375, 'x[5] <= 0.64\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1, 0, 0, 0]'),
#  Text(0.1956521739130435, 0.2916666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2391304347826087, 0.2916666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.2608695652173913, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.2826086956521739, 0.4583333333333333, 'gini = 0.0\nsamples = 6\nvalue = [6, 0, 0, 0, 0, 0]'),
#  Text(0.30434782608695654, 0.5416666666666666, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0, 0, 0]'),
#  Text(0.391304347826087, 0.625, 'x[8] <= 0.225\ngini = 0.191\nsamples = 28\nvalue = [3, 25, 0, 0, 0, 0]'),
#  Text(0.34782608695652173, 0.5416666666666666, 'x[6] <= 7.805\ngini = 0.08\nsamples = 24\nvalue = [1, 23, 0, 0, 0, 0]'),
#  Text(0.32608695652173914, 0.4583333333333333, 'x[3] <= 1.64\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0, 0, 0, 0]'),
#  Text(0.30434782608695654, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.34782608695652173, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.3695652173913043, 0.4583333333333333, 'gini = 0.0\nsamples = 21\nvalue = [0, 21, 0, 0, 0, 0]'),
#  Text(0.43478260869565216, 0.5416666666666666, 'x[1] <= 12.82\ngini = 0.5\nsamples = 4\nvalue = [2, 2, 0, 0, 0, 0]'),
#  Text(0.41304347826086957, 0.4583333333333333, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0]'),
#  Text(0.45652173913043476, 0.4583333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.6413043478260869, 0.7083333333333334, 'x[0] <= 1.517\ngini = 0.56\nsamples = 76\nvalue = [46, 16, 13, 0, 0, 1]'),
#  Text(0.5, 0.625, 'x[3] <= 1.22\ngini = 0.56\nsamples = 10\nvalue = [2, 2, 6, 0, 0, 0]'),
#  Text(0.4782608695652174, 0.5416666666666666, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0]'),
#  Text(0.5217391304347826, 0.5416666666666666, 'x[2] <= 3.285\ngini = 0.375\nsamples = 8\nvalue = [0, 2, 6, 0, 0, 0]'),
#  Text(0.5, 0.4583333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.5434782608695652, 0.4583333333333333, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.782608695652174, 0.625, 'x[8] <= 0.115\ngini = 0.499\nsamples = 66\nvalue = [44, 14, 7, 0, 0, 1]'),
#  Text(0.6521739130434783, 0.5416666666666666, 'x[2] <= 3.39\ngini = 0.397\nsamples = 46\nvalue = [35, 5, 5, 0, 0, 1]'),
#  Text(0.5869565217391305, 0.4583333333333333, 'x[3] <= 1.485\ngini = 0.719\nsamples = 8\nvalue = [3, 2, 2, 0, 0, 1]'),
#  Text(0.5652173913043478, 0.375, 'x[0] <= 1.521\ngini = 0.611\nsamples = 6\nvalue = [3, 2, 0, 0, 0, 1]'),
#  Text(0.5217391304347826, 0.2916666666666667, 'x[1] <= 13.08\ngini = 0.375\nsamples = 4\nvalue = [3, 1, 0, 0, 0, 0]'),
#  Text(0.5, 0.20833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.5434782608695652, 0.20833333333333334, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0, 0]'),
#  Text(0.6086956521739131, 0.2916666666666667, 'x[0] <= 1.525\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 0, 0, 1]'),
#  Text(0.5869565217391305, 0.20833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.6304347826086957, 0.20833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.6086956521739131, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.717391304347826, 0.4583333333333333, 'x[2] <= 3.88\ngini = 0.278\nsamples = 38\nvalue = [32, 3, 3, 0, 0, 0]'),
#  Text(0.6739130434782609, 0.375, 'x[2] <= 3.635\ngini = 0.204\nsamples = 36\nvalue = [32, 2, 2, 0, 0, 0]'),
#  Text(0.6521739130434783, 0.2916666666666667, 'gini = 0.0\nsamples = 22\nvalue = [22, 0, 0, 0, 0, 0]'),
#  Text(0.6956521739130435, 0.2916666666666667, 'x[6] <= 8.54\ngini = 0.449\nsamples = 14\nvalue = [10, 2, 2, 0, 0, 0]'),
#  Text(0.6739130434782609, 0.20833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.717391304347826, 0.20833333333333334, 'x[0] <= 1.518\ngini = 0.278\nsamples = 12\nvalue = [10, 0, 2, 0, 0, 0]'),
#  Text(0.6956521739130435, 0.125, 'x[3] <= 1.19\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 2, 0, 0, 0]'),
#  Text(0.6739130434782609, 0.041666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.717391304347826, 0.041666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.7391304347826086, 0.125, 'gini = 0.0\nsamples = 9\nvalue = [9, 0, 0, 0, 0, 0]'),
#  Text(0.7608695652173914, 0.375, 'x[5] <= 0.3\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.7391304347826086, 0.2916666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.782608695652174, 0.2916666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.9130434782608695, 0.5416666666666666, 'x[2] <= 3.655\ngini = 0.585\nsamples = 20\nvalue = [9, 9, 2, 0, 0, 0]'),
#  Text(0.8695652173913043, 0.4583333333333333, 'x[3] <= 1.17\ngini = 0.5\nsamples = 14\nvalue = [9, 4, 1, 0, 0, 0]'),
#  Text(0.8478260869565217, 0.375, 'x[0] <= 1.519\ngini = 0.594\nsamples = 8\nvalue = [3, 4, 1, 0, 0, 0]'),
#  Text(0.8260869565217391, 0.2916666666666667, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0, 0, 0]'),
#  Text(0.8695652173913043, 0.2916666666666667, 'x[7] <= 0.075\ngini = 0.375\nsamples = 4\nvalue = [3, 0, 1, 0, 0, 0]'),
#  Text(0.8478260869565217, 0.20833333333333334, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0, 0]'),
#  Text(0.8913043478260869, 0.20833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8913043478260869, 0.375, 'gini = 0.0\nsamples = 6\nvalue = [6, 0, 0, 0, 0, 0]'),
#  Text(0.9565217391304348, 0.4583333333333333, 'x[4] <= 71.82\ngini = 0.278\nsamples = 6\nvalue = [0, 5, 1, 0, 0, 0]'),
#  Text(0.9347826086956522, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9782608695652174, 0.375, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0, 0, 0]'),
#  Text(0.7282608695652174, 0.875, 'x[8] <= 0.185\ngini = 0.169\nsamples = 22\nvalue = [1, 1, 0, 0, 0, 20]'),
#  Text(0.6195652173913044, 0.9166666666666667, '  False'),
#  Text(0.7065217391304348, 0.7916666666666666, 'x[2] <= 3.39\ngini = 0.091\nsamples = 21\nvalue = [1, 0, 0, 0, 0, 20]'),
#  Text(0.6847826086956522, 0.7083333333333334, 'gini = 0.0\nsamples = 20\nvalue = [0, 0, 0, 0, 0, 20]'),
#  Text(0.7282608695652174, 0.7083333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.75, 0.7916666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]')]

# %%
y_pred = clf.predict(X_test)

# %%
(y_pred == y_test).sum() / len(y_pred)
# Out:
# np.float64(0.7674418604651163)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7674418604651163

# %%
print(classification_report(y_test, y_pred))
# Out:
# '              precision    recall  f1-score   support\n\n           1       0.79      0.85      0.81        13\n           2       1.00      0.71      0.83        17\n           3       0.17      0.33      0.22         3\n           5       1.00      0.50      0.67         2\n           6       1.00      1.00      1.00         2\n           7       0.75      1.00      0.86         6\n\n    accuracy                           0.77        43\n   macro avg       0.78      0.73      0.73        43\nweighted avg       0.84      0.77      0.79        43\n'
