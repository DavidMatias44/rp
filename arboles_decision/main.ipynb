# %%
import pandas as pd
from sklearn import tree 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./glass.csv')
df
# Out:
#       ID       RI   NA2O   MGO  AL2O3   SIO2   K2O   CAO   BAO  FE2O3  TYPE
# 0      1  1.52101  13.64  4.49   1.10  71.78  0.06  8.75  0.00    0.0     1
# 1      2  1.51761  13.89  3.60   1.36  72.73  0.48  7.83  0.00    0.0     1
# 2      3  1.51618  13.53  3.55   1.54  72.99  0.39  7.78  0.00    0.0     1
# 3      4  1.51766  13.21  3.69   1.29  72.61  0.57  8.22  0.00    0.0     1
# 4      5  1.51742  13.27  3.62   1.24  73.08  0.55  8.07  0.00    0.0     1
# ..   ...      ...    ...   ...    ...    ...   ...   ...   ...    ...   ...
# 209  210  1.51623  14.14  0.00   2.88  72.61  0.08  9.18  1.06    0.0     7
# 210  211  1.51685  14.92  0.00   1.99  73.06  0.00  8.40  1.59    0.0     7
# 211  212  1.52065  14.36  0.00   2.02  73.42  0.00  8.44  1.64    0.0     7
# 212  213  1.51651  14.38  0.00   1.94  73.61  0.00  8.48  1.57    0.0     7
# 213  214  1.51711  14.23  0.00   2.08  73.36  0.00  8.62  1.67    0.0     7
#
# [214 rows x 11 columns]

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       ID       RI   NA2O   MGO  AL2O3   SIO2   K2O   CAO   BAO  FE2O3  TYPE
# 0      1  1.52101  13.64  4.49   1.10  71.78  0.06  8.75  0.00    0.0     1
# 1      2  1.51761  13.89  3.60   1.36  72.73  0.48  7.83  0.00    0.0     1
# 2      3  1.51618  13.53  3.55   1.54  72.99  0.39  7.78  0.00    0.0     1
# 3      4  1.51766  13.21  3.69   1.29  72.61  0.57  8.22  0.00    0.0     1
# 4      5  1.51742  13.27  3.62   1.24  73.08  0.55  8.07  0.00    0.0     1
# ..   ...      ...    ...   ...    ...    ...   ...   ...   ...    ...   ...
# 209  210  1.51623  14.14  0.00   2.88  72.61  0.08  9.18  1.06    0.0     7
# 210  211  1.51685  14.92  0.00   1.99  73.06  0.00  8.40  1.59    0.0     7
# 211  212  1.52065  14.36  0.00   2.02  73.42  0.00  8.44  1.64    0.0     7
# 212  213  1.51651  14.38  0.00   1.94  73.61  0.00  8.48  1.57    0.0     7
# 213  214  1.51711  14.23  0.00   2.08  73.36  0.00  8.62  1.67    0.0     7
#
# [214 rows x 11 columns]>

# %%
X = df.drop(['ID', 'TYPE'], axis=1)
X
# Out:
#           RI   NA2O   MGO  AL2O3   SIO2   K2O   CAO   BAO  FE2O3
# 0    1.52101  13.64  4.49   1.10  71.78  0.06  8.75  0.00    0.0
# 1    1.51761  13.89  3.60   1.36  72.73  0.48  7.83  0.00    0.0
# 2    1.51618  13.53  3.55   1.54  72.99  0.39  7.78  0.00    0.0
# 3    1.51766  13.21  3.69   1.29  72.61  0.57  8.22  0.00    0.0
# 4    1.51742  13.27  3.62   1.24  73.08  0.55  8.07  0.00    0.0
# ..       ...    ...   ...    ...    ...   ...   ...   ...    ...
# 209  1.51623  14.14  0.00   2.88  72.61  0.08  9.18  1.06    0.0
# 210  1.51685  14.92  0.00   1.99  73.06  0.00  8.40  1.59    0.0
# 211  1.52065  14.36  0.00   2.02  73.42  0.00  8.44  1.64    0.0
# 212  1.51651  14.38  0.00   1.94  73.61  0.00  8.48  1.57    0.0
# 213  1.51711  14.23  0.00   2.08  73.36  0.00  8.62  1.67    0.0
#
# [214 rows x 9 columns]

# %%
y = df['TYPE']
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 209    7
# 210    7
# 211    7
# 212    7
# 213    7
# Name: TYPE, Length: 214, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=69)

# %%
clf = tree.DecisionTreeClassifier(random_state=23, max_depth=7)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=6, random_state=23)

# %%
plt.figure(figsize=(40, 25))
tree.plot_tree(
    clf,
    feature_names=X.columns,
    class_names=y.astype(str).unique(),
    filled=True,
    rounded=True,
    fontsize=10
)
# Out:
# [Text(0.7326388888888888, 0.9285714285714286, 'BAO <= 0.335\ngini = 0.732\nsamples = 171\nvalue = [56, 62, 14, 8, 8, 23]\nclass = 2'),
#  Text(0.5486111111111112, 0.7857142857142857, 'AL2O3 <= 1.405\ngini = 0.677\nsamples = 148\nvalue = [55, 61, 14, 8, 8, 2]\nclass = 2'),
#  Text(0.640625, 0.8571428571428572, 'True  '),
#  Text(0.3611111111111111, 0.6428571428571429, 'CAO <= 10.58\ngini = 0.616\nsamples = 90\nvalue = [49.0, 24.0, 11.0, 1.0, 3.0, 2.0]\nclass = 1'),
#  Text(0.2222222222222222, 0.5, 'RI <= 1.517\ngini = 0.565\nsamples = 80\nvalue = [49, 16, 11, 0, 2, 2]\nclass = 1'),
#  Text(0.1111111111111111, 0.35714285714285715, 'RI <= 1.516\ngini = 0.703\nsamples = 16\nvalue = [3, 4, 7, 0, 1, 1]\nclass = 3'),
#  Text(0.05555555555555555, 0.21428571428571427, 'SIO2 <= 74.345\ngini = 0.375\nsamples = 4\nvalue = [3, 0, 0, 0, 1, 0]\nclass = 1'),
#  Text(0.027777777777777776, 0.07142857142857142, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0, 0]\nclass = 1'),
#  Text(0.08333333333333333, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 6'),
#  Text(0.16666666666666666, 0.21428571428571427, 'SIO2 <= 72.725\ngini = 0.542\nsamples = 12\nvalue = [0, 4, 7, 0, 0, 1]\nclass = 3'),
#  Text(0.1388888888888889, 0.07142857142857142, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]\nclass = 3'),
#  Text(0.19444444444444445, 0.07142857142857142, 'gini = 0.571\nsamples = 7\nvalue = [0, 4, 2, 0, 0, 1]\nclass = 2'),
#  Text(0.3333333333333333, 0.35714285714285715, 'FE2O3 <= 0.185\ngini = 0.444\nsamples = 64\nvalue = [46, 12, 4, 0, 1, 1]\nclass = 1'),
#  Text(0.2777777777777778, 0.21428571428571427, 'MGO <= 3.825\ngini = 0.344\nsamples = 55\nvalue = [44, 6, 3, 0, 1, 1]\nclass = 1'),
#  Text(0.25, 0.07142857142857142, 'gini = 0.234\nsamples = 47\nvalue = [41, 2, 2, 0, 1, 1]\nclass = 1'),
#  Text(0.3055555555555556, 0.07142857142857142, 'gini = 0.594\nsamples = 8\nvalue = [3, 4, 1, 0, 0, 0]\nclass = 2'),
#  Text(0.3888888888888889, 0.21428571428571427, 'FE2O3 <= 0.36\ngini = 0.494\nsamples = 9\nvalue = [2, 6, 1, 0, 0, 0]\nclass = 2'),
#  Text(0.3611111111111111, 0.07142857142857142, 'gini = 0.375\nsamples = 8\nvalue = [2, 6, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.4166666666666667, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 3'),
#  Text(0.5, 0.5, 'AL2O3 <= 1.38\ngini = 0.34\nsamples = 10\nvalue = [0, 8, 0, 1, 1, 0]\nclass = 2'),
#  Text(0.4722222222222222, 0.35714285714285715, 'NA2O <= 14.495\ngini = 0.198\nsamples = 9\nvalue = [0, 8, 0, 0, 1, 0]\nclass = 2'),
#  Text(0.4444444444444444, 0.21428571428571427, 'gini = 0.0\nsamples = 8\nvalue = [0, 8, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.5, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 6'),
#  Text(0.5277777777777778, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 5'),
#  Text(0.7361111111111112, 0.6428571428571429, 'MGO <= 2.74\ngini = 0.558\nsamples = 58\nvalue = [6, 37, 3, 7, 5, 0]\nclass = 2'),
#  Text(0.6111111111111112, 0.5, 'K2O <= 0.065\ngini = 0.648\nsamples = 16\nvalue = [0, 4, 0, 7, 5, 0]\nclass = 5'),
#  Text(0.5833333333333334, 0.35714285714285715, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]\nclass = 6'),
#  Text(0.6388888888888888, 0.35714285714285715, 'FE2O3 <= 0.085\ngini = 0.463\nsamples = 11\nvalue = [0, 4, 0, 7, 0, 0]\nclass = 5'),
#  Text(0.6111111111111112, 0.21428571428571427, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]\nclass = 5'),
#  Text(0.6666666666666666, 0.21428571428571427, 'SIO2 <= 72.79\ngini = 0.32\nsamples = 5\nvalue = [0, 4, 0, 1, 0, 0]\nclass = 2'),
#  Text(0.6388888888888888, 0.07142857142857142, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.6944444444444444, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 5'),
#  Text(0.8611111111111112, 0.5, 'CAO <= 8.695\ngini = 0.357\nsamples = 42\nvalue = [6, 33, 3, 0, 0, 0]\nclass = 2'),
#  Text(0.8333333333333334, 0.35714285714285715, 'NA2O <= 12.835\ngini = 0.26\nsamples = 39\nvalue = [6, 33, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.7777777777777778, 0.21428571428571427, 'FE2O3 <= 0.14\ngini = 0.5\nsamples = 8\nvalue = [4, 4, 0, 0, 0, 0]\nclass = 1'),
#  Text(0.75, 0.07142857142857142, 'gini = 0.32\nsamples = 5\nvalue = [1, 4, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.8055555555555556, 0.07142857142857142, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0, 0]\nclass = 1'),
#  Text(0.8888888888888888, 0.21428571428571427, 'K2O <= 0.545\ngini = 0.121\nsamples = 31\nvalue = [2, 29, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.8611111111111112, 0.07142857142857142, 'gini = 0.346\nsamples = 9\nvalue = [2, 7, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.9166666666666666, 0.07142857142857142, 'gini = 0.0\nsamples = 22\nvalue = [0, 22, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.8888888888888888, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 3'),
#  Text(0.9166666666666666, 0.7857142857142857, 'SIO2 <= 70.12\ngini = 0.163\nsamples = 23\nvalue = [1, 1, 0, 0, 0, 21]\nclass = 7'),
#  Text(0.8246527777777777, 0.8571428571428572, '  False'),
#  Text(0.8888888888888888, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.9444444444444444, 0.6428571428571429, 'MGO <= 3.42\ngini = 0.087\nsamples = 22\nvalue = [1, 0, 0, 0, 0, 21]\nclass = 7'),
#  Text(0.9166666666666666, 0.5, 'gini = 0.0\nsamples = 21\nvalue = [0, 0, 0, 0, 0, 21]\nclass = 7'),
#  Text(0.9722222222222222, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]\nclass = 1')]

# %% [markdown]
# ### Se obtienen las importancias de las características.

# %%
importancias = clf.feature_importances_
importancias
# Out:
# array([0.08974206, 0.04287855, 0.12335506, 0.14387258, 0.07604129,
#        0.06053505, 0.11967357, 0.21749074, 0.12641111])

# %% [markdown]
# ### Se crea un nuevo DataFrame con las importancias.

# %%
importancias_df = pd.DataFrame(
    {'feature': X.columns, 'importance': importancias}
)
importancias_df = importancias_df.sort_values(
    'importance', ascending=False
)
importancias_df
# Out:
#   feature  importance
# 7     BAO    0.217491
# 3   AL2O3    0.143873
# 8   FE2O3    0.126411
# 2     MGO    0.123355
# 6     CAO    0.119674
# 0      RI    0.089742
# 4    SIO2    0.076041
# 5     K2O    0.060535
# 1    NA2O    0.042879

# %% [markdown]
# ### Se seleccionan las mejor k características.

# %%
k = 4
mejores = importancias_df['feature'].head(k).values
mejores
# Out:
# array(['BAO', 'AL2O3', 'FE2O3', 'MGO'], dtype=object)

# %%
X_mejorado = X[mejores]
X_mejorado
# Out:
#       BAO  AL2O3  FE2O3   MGO
# 0    0.00   1.10    0.0  4.49
# 1    0.00   1.36    0.0  3.60
# 2    0.00   1.54    0.0  3.55
# 3    0.00   1.29    0.0  3.69
# 4    0.00   1.24    0.0  3.62
# ..    ...    ...    ...   ...
# 209  1.06   2.88    0.0  0.00
# 210  1.59   1.99    0.0  0.00
# 211  1.64   2.02    0.0  0.00
# 212  1.57   1.94    0.0  0.00
# 213  1.67   2.08    0.0  0.00
#
# [214 rows x 4 columns]

# %%
svm = SVC(kernel='linear')

# %% [markdown]
# ### Se dividen los datos MEJORADOS. Se entrena y se evalúa.

# %%
X_train_mejorado, X_test_mejorado, y_train, y_test = train_test_split(X_mejorado, y, test_size=0.2, random_state=23)

# %%
svm.fit(X_train_mejorado, y_train)
y_pred = svm.predict(X_test_mejorado)
print(f"Error: {1 - accuracy_score(y_pred, y_test)}")
# Out:
# Error: 0.2558139534883721

# %% [markdown]
# ### Se dividen los datos NO mejorados. Se entrena y se evalúa.

# %%
X_train, X_mejorado, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=23)

# %%
svm.fit(X_train, y_train)
y_pred = svm.predict(X_test)
print(f"Error: {1 - accuracy_score(y_pred, y_test)}")
# Out:
# Error: 0.6976744186046512
