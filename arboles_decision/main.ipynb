# %%
import pandas as pd
from sklearn import tree 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./glass.csv')
df
# Out:
#       ID       RI   NA2O   MGO  AL2O3   SIO2   K2O   CAO   BAO  FE2O3  TYPE
# 0      1  1.52101  13.64  4.49   1.10  71.78  0.06  8.75  0.00    0.0     1
# 1      2  1.51761  13.89  3.60   1.36  72.73  0.48  7.83  0.00    0.0     1
# 2      3  1.51618  13.53  3.55   1.54  72.99  0.39  7.78  0.00    0.0     1
# 3      4  1.51766  13.21  3.69   1.29  72.61  0.57  8.22  0.00    0.0     1
# 4      5  1.51742  13.27  3.62   1.24  73.08  0.55  8.07  0.00    0.0     1
# ..   ...      ...    ...   ...    ...    ...   ...   ...   ...    ...   ...
# 209  210  1.51623  14.14  0.00   2.88  72.61  0.08  9.18  1.06    0.0     7
# 210  211  1.51685  14.92  0.00   1.99  73.06  0.00  8.40  1.59    0.0     7
# 211  212  1.52065  14.36  0.00   2.02  73.42  0.00  8.44  1.64    0.0     7
# 212  213  1.51651  14.38  0.00   1.94  73.61  0.00  8.48  1.57    0.0     7
# 213  214  1.51711  14.23  0.00   2.08  73.36  0.00  8.62  1.67    0.0     7
#
# [214 rows x 11 columns]

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       ID       RI   NA2O   MGO  AL2O3   SIO2   K2O   CAO   BAO  FE2O3  TYPE
# 0      1  1.52101  13.64  4.49   1.10  71.78  0.06  8.75  0.00    0.0     1
# 1      2  1.51761  13.89  3.60   1.36  72.73  0.48  7.83  0.00    0.0     1
# 2      3  1.51618  13.53  3.55   1.54  72.99  0.39  7.78  0.00    0.0     1
# 3      4  1.51766  13.21  3.69   1.29  72.61  0.57  8.22  0.00    0.0     1
# 4      5  1.51742  13.27  3.62   1.24  73.08  0.55  8.07  0.00    0.0     1
# ..   ...      ...    ...   ...    ...    ...   ...   ...   ...    ...   ...
# 209  210  1.51623  14.14  0.00   2.88  72.61  0.08  9.18  1.06    0.0     7
# 210  211  1.51685  14.92  0.00   1.99  73.06  0.00  8.40  1.59    0.0     7
# 211  212  1.52065  14.36  0.00   2.02  73.42  0.00  8.44  1.64    0.0     7
# 212  213  1.51651  14.38  0.00   1.94  73.61  0.00  8.48  1.57    0.0     7
# 213  214  1.51711  14.23  0.00   2.08  73.36  0.00  8.62  1.67    0.0     7
#
# [214 rows x 11 columns]>

# %%
X = df.drop(['ID', 'TYPE'], axis=1)
X
# Out:
#           RI   NA2O   MGO  AL2O3   SIO2   K2O   CAO   BAO  FE2O3
# 0    1.52101  13.64  4.49   1.10  71.78  0.06  8.75  0.00    0.0
# 1    1.51761  13.89  3.60   1.36  72.73  0.48  7.83  0.00    0.0
# 2    1.51618  13.53  3.55   1.54  72.99  0.39  7.78  0.00    0.0
# 3    1.51766  13.21  3.69   1.29  72.61  0.57  8.22  0.00    0.0
# 4    1.51742  13.27  3.62   1.24  73.08  0.55  8.07  0.00    0.0
# ..       ...    ...   ...    ...    ...   ...   ...   ...    ...
# 209  1.51623  14.14  0.00   2.88  72.61  0.08  9.18  1.06    0.0
# 210  1.51685  14.92  0.00   1.99  73.06  0.00  8.40  1.59    0.0
# 211  1.52065  14.36  0.00   2.02  73.42  0.00  8.44  1.64    0.0
# 212  1.51651  14.38  0.00   1.94  73.61  0.00  8.48  1.57    0.0
# 213  1.51711  14.23  0.00   2.08  73.36  0.00  8.62  1.67    0.0
#
# [214 rows x 9 columns]

# %%
y = df['TYPE']
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 209    7
# 210    7
# 211    7
# 212    7
# 213    7
# Name: TYPE, Length: 214, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=69)

# %%
clf = tree.DecisionTreeClassifier(random_state=69)
clf = clf.fit(X_train, y_train)

# %%
plt.figure(figsize=(40, 25))
tree.plot_tree(
    clf,
    feature_names=X.columns,
    class_names=y.astype(str).unique(),
    filled=True,
    rounded=True,
    fontsize=10
)
# Out:
# [Text(0.7704529494382022, 0.9615384615384616, 'BAO <= 0.335\ngini = 0.732\nsamples = 171\nvalue = [56, 62, 14, 8, 8, 23]\nclass = 2'),
#  Text(0.5858497191011236, 0.8846153846153846, 'AL2O3 <= 1.405\ngini = 0.677\nsamples = 148\nvalue = [55, 61, 14, 8, 8, 2]\nclass = 2'),
#  Text(0.6781513342696629, 0.9230769230769231, 'True  '),
#  Text(0.40765449438202245, 0.8076923076923077, 'CAO <= 10.58\ngini = 0.616\nsamples = 90\nvalue = [49.0, 24.0, 11.0, 1.0, 3.0, 2.0]\nclass = 1'),
#  Text(0.2422752808988764, 0.7307692307692307, 'RI <= 1.517\ngini = 0.565\nsamples = 80\nvalue = [49, 16, 11, 0, 2, 2]\nclass = 1'),
#  Text(0.0898876404494382, 0.6538461538461539, 'RI <= 1.516\ngini = 0.703\nsamples = 16\nvalue = [3, 4, 7, 0, 1, 1]\nclass = 3'),
#  Text(0.0449438202247191, 0.5769230769230769, 'MGO <= 1.715\ngini = 0.375\nsamples = 4\nvalue = [3, 0, 0, 0, 1, 0]\nclass = 1'),
#  Text(0.02247191011235955, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 6'),
#  Text(0.06741573033707865, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0, 0]\nclass = 1'),
#  Text(0.1348314606741573, 0.5769230769230769, 'AL2O3 <= 1.27\ngini = 0.542\nsamples = 12\nvalue = [0, 4, 7, 0, 0, 1]\nclass = 3'),
#  Text(0.11235955056179775, 0.5, 'MGO <= 3.46\ngini = 0.571\nsamples = 7\nvalue = [0, 4, 2, 0, 0, 1]\nclass = 2'),
#  Text(0.0898876404494382, 0.4230769230769231, 'RI <= 1.516\ngini = 0.625\nsamples = 4\nvalue = [0, 1, 2, 0, 0, 1]\nclass = 3'),
#  Text(0.06741573033707865, 0.34615384615384615, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]\nclass = 3'),
#  Text(0.11235955056179775, 0.34615384615384615, 'AL2O3 <= 1.21\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 0, 0, 1]\nclass = 2'),
#  Text(0.0898876404494382, 0.2692307692307692, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]\nclass = 7'),
#  Text(0.1348314606741573, 0.2692307692307692, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.1348314606741573, 0.4230769230769231, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.15730337078651685, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]\nclass = 3'),
#  Text(0.3946629213483146, 0.6538461538461539, 'FE2O3 <= 0.185\ngini = 0.444\nsamples = 64\nvalue = [46, 12, 4, 0, 1, 1]\nclass = 1'),
#  Text(0.3061797752808989, 0.5769230769230769, 'MGO <= 3.825\ngini = 0.344\nsamples = 55\nvalue = [44, 6, 3, 0, 1, 1]\nclass = 1'),
#  Text(0.24157303370786518, 0.5, 'MGO <= 2.61\ngini = 0.234\nsamples = 47\nvalue = [41, 2, 2, 0, 1, 1]\nclass = 1'),
#  Text(0.21910112359550563, 0.4230769230769231, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 6'),
#  Text(0.2640449438202247, 0.4230769230769231, 'AL2O3 <= 0.68\ngini = 0.201\nsamples = 46\nvalue = [41, 2, 2, 0, 0, 1]\nclass = 1'),
#  Text(0.20224719101123595, 0.34615384615384615, 'RI <= 1.522\ngini = 0.48\nsamples = 5\nvalue = [3, 0, 2, 0, 0, 0]\nclass = 1'),
#  Text(0.1797752808988764, 0.2692307692307692, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]\nclass = 3'),
#  Text(0.2247191011235955, 0.2692307692307692, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0, 0]\nclass = 1'),
#  Text(0.3258426966292135, 0.34615384615384615, 'RI <= 1.523\ngini = 0.138\nsamples = 41\nvalue = [38, 2, 0, 0, 0, 1]\nclass = 1'),
#  Text(0.2696629213483146, 0.2692307692307692, 'MGO <= 3.75\ngini = 0.097\nsamples = 39\nvalue = [37, 2, 0, 0, 0, 0]\nclass = 1'),
#  Text(0.2247191011235955, 0.19230769230769232, 'FE2O3 <= 0.145\ngini = 0.054\nsamples = 36\nvalue = [35, 1, 0, 0, 0, 0]\nclass = 1'),
#  Text(0.20224719101123595, 0.11538461538461539, 'gini = 0.0\nsamples = 32\nvalue = [32, 0, 0, 0, 0, 0]\nclass = 1'),
#  Text(0.24719101123595505, 0.11538461538461539, 'FE2O3 <= 0.155\ngini = 0.375\nsamples = 4\nvalue = [3, 1, 0, 0, 0, 0]\nclass = 1'),
#  Text(0.2247191011235955, 0.038461538461538464, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.2696629213483146, 0.038461538461538464, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0, 0]\nclass = 1'),
#  Text(0.3146067415730337, 0.19230769230769232, 'AL2O3 <= 1.055\ngini = 0.444\nsamples = 3\nvalue = [2, 1, 0, 0, 0, 0]\nclass = 1'),
#  Text(0.29213483146067415, 0.11538461538461539, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0]\nclass = 1'),
#  Text(0.33707865168539325, 0.11538461538461539, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.38202247191011235, 0.2692307692307692, 'NA2O <= 13.715\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 0, 0, 1]\nclass = 1'),
#  Text(0.3595505617977528, 0.19230769230769232, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]\nclass = 7'),
#  Text(0.4044943820224719, 0.19230769230769232, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]\nclass = 1'),
#  Text(0.3707865168539326, 0.5, 'NA2O <= 13.55\ngini = 0.594\nsamples = 8\nvalue = [3, 4, 1, 0, 0, 0]\nclass = 2'),
#  Text(0.34831460674157305, 0.4230769230769231, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.39325842696629215, 0.4230769230769231, 'K2O <= 0.03\ngini = 0.375\nsamples = 4\nvalue = [3, 0, 1, 0, 0, 0]\nclass = 1'),
#  Text(0.3707865168539326, 0.34615384615384615, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 3'),
#  Text(0.4157303370786517, 0.34615384615384615, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0, 0]\nclass = 1'),
#  Text(0.48314606741573035, 0.5769230769230769, 'SIO2 <= 71.66\ngini = 0.494\nsamples = 9\nvalue = [2, 6, 1, 0, 0, 0]\nclass = 2'),
#  Text(0.4606741573033708, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 3'),
#  Text(0.5056179775280899, 0.5, 'RI <= 1.518\ngini = 0.375\nsamples = 8\nvalue = [2, 6, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.48314606741573035, 0.4230769230769231, 'NA2O <= 12.325\ngini = 0.444\nsamples = 3\nvalue = [2, 1, 0, 0, 0, 0]\nclass = 1'),
#  Text(0.4606741573033708, 0.34615384615384615, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.5056179775280899, 0.34615384615384615, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0]\nclass = 1'),
#  Text(0.5280898876404494, 0.4230769230769231, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.5730337078651685, 0.7307692307692307, 'NA2O <= 14.495\ngini = 0.34\nsamples = 10\nvalue = [0, 8, 0, 1, 1, 0]\nclass = 2'),
#  Text(0.550561797752809, 0.6538461538461539, 'AL2O3 <= 1.38\ngini = 0.198\nsamples = 9\nvalue = [0, 8, 0, 1, 0, 0]\nclass = 2'),
#  Text(0.5280898876404494, 0.5769230769230769, 'gini = 0.0\nsamples = 8\nvalue = [0, 8, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.5730337078651685, 0.5769230769230769, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 5'),
#  Text(0.5955056179775281, 0.6538461538461539, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 6'),
#  Text(0.7640449438202247, 0.8076923076923077, 'MGO <= 2.74\ngini = 0.558\nsamples = 58\nvalue = [6, 37, 3, 7, 5, 0]\nclass = 2'),
#  Text(0.6629213483146067, 0.7307692307692307, 'K2O <= 0.065\ngini = 0.648\nsamples = 16\nvalue = [0, 4, 0, 7, 5, 0]\nclass = 5'),
#  Text(0.6404494382022472, 0.6538461538461539, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]\nclass = 6'),
#  Text(0.6853932584269663, 0.6538461538461539, 'FE2O3 <= 0.085\ngini = 0.463\nsamples = 11\nvalue = [0, 4, 0, 7, 0, 0]\nclass = 5'),
#  Text(0.6629213483146067, 0.5769230769230769, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]\nclass = 5'),
#  Text(0.7078651685393258, 0.5769230769230769, 'SIO2 <= 72.79\ngini = 0.32\nsamples = 5\nvalue = [0, 4, 0, 1, 0, 0]\nclass = 2'),
#  Text(0.6853932584269663, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.7303370786516854, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 5'),
#  Text(0.8651685393258427, 0.7307692307692307, 'CAO <= 8.695\ngini = 0.357\nsamples = 42\nvalue = [6, 33, 3, 0, 0, 0]\nclass = 2'),
#  Text(0.8426966292134831, 0.6538461538461539, 'NA2O <= 12.835\ngini = 0.26\nsamples = 39\nvalue = [6, 33, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.797752808988764, 0.5769230769230769, 'SIO2 <= 73.215\ngini = 0.5\nsamples = 8\nvalue = [4, 4, 0, 0, 0, 0]\nclass = 1'),
#  Text(0.7752808988764045, 0.5, 'AL2O3 <= 1.76\ngini = 0.32\nsamples = 5\nvalue = [4, 1, 0, 0, 0, 0]\nclass = 1'),
#  Text(0.7528089887640449, 0.4230769230769231, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0, 0, 0]\nclass = 1'),
#  Text(0.797752808988764, 0.4230769230769231, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.8202247191011236, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.8876404494382022, 0.5769230769230769, 'K2O <= 0.545\ngini = 0.121\nsamples = 31\nvalue = [2, 29, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.8651685393258427, 0.5, 'SIO2 <= 72.725\ngini = 0.346\nsamples = 9\nvalue = [2, 7, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.8426966292134831, 0.4230769230769231, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.8876404494382022, 0.4230769230769231, 'RI <= 1.516\ngini = 0.48\nsamples = 5\nvalue = [2, 3, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.8651685393258427, 0.34615384615384615, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.9101123595505618, 0.34615384615384615, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0]\nclass = 1'),
#  Text(0.9101123595505618, 0.5, 'gini = 0.0\nsamples = 22\nvalue = [0, 22, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.8876404494382022, 0.6538461538461539, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 3'),
#  Text(0.9550561797752809, 0.8846153846153846, 'MGO <= 3.42\ngini = 0.163\nsamples = 23\nvalue = [1, 1, 0, 0, 0, 21]\nclass = 7'),
#  Text(0.8627545646067416, 0.9230769230769231, '  False'),
#  Text(0.9325842696629213, 0.8076923076923077, 'BAO <= 3.015\ngini = 0.087\nsamples = 22\nvalue = [0, 1, 0, 0, 0, 21]\nclass = 7'),
#  Text(0.9101123595505618, 0.7307692307692307, 'gini = 0.0\nsamples = 21\nvalue = [0, 0, 0, 0, 0, 21]\nclass = 7'),
#  Text(0.9550561797752809, 0.7307692307692307, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 2'),
#  Text(0.9775280898876404, 0.8076923076923077, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]\nclass = 1')]

# %%
y_pred = clf.predict(X_test)

# %%
print(f"Error: {1 - accuracy_score(y_test, y_pred)}")
# Out:
# Error: 0.34883720930232553

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.73      0.79      0.76        14
#            2       0.62      0.57      0.59        14
#            3       0.00      0.00      0.00         3
#            5       0.60      0.60      0.60         5
#            6       1.00      1.00      1.00         1
#            7       0.83      0.83      0.83         6
#
#     accuracy                           0.65        43
#    macro avg       0.63      0.63      0.63        43
# weighted avg       0.65      0.65      0.65        43
