# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import mutual_info_classif
from sklearn.metrics import accuracy_score, classification_report
from sklearn.svm import SVC
from sklearn import tree

# %%
df = pd.read_csv('./glass.csv')
df
# Out:
#       ID       RI   NA2O   MGO  AL2O3   SIO2   K2O   CAO   BAO  FE2O3  TYPE
# 0      1  1.52101  13.64  4.49   1.10  71.78  0.06  8.75  0.00    0.0     1
# 1      2  1.51761  13.89  3.60   1.36  72.73  0.48  7.83  0.00    0.0     1
# 2      3  1.51618  13.53  3.55   1.54  72.99  0.39  7.78  0.00    0.0     1
# 3      4  1.51766  13.21  3.69   1.29  72.61  0.57  8.22  0.00    0.0     1
# 4      5  1.51742  13.27  3.62   1.24  73.08  0.55  8.07  0.00    0.0     1
# ..   ...      ...    ...   ...    ...    ...   ...   ...   ...    ...   ...
# 209  210  1.51623  14.14  0.00   2.88  72.61  0.08  9.18  1.06    0.0     7
# 210  211  1.51685  14.92  0.00   1.99  73.06  0.00  8.40  1.59    0.0     7
# 211  212  1.52065  14.36  0.00   2.02  73.42  0.00  8.44  1.64    0.0     7
# 212  213  1.51651  14.38  0.00   1.94  73.61  0.00  8.48  1.57    0.0     7
# 213  214  1.51711  14.23  0.00   2.08  73.36  0.00  8.62  1.67    0.0     7
#
# [214 rows x 11 columns]

# %%
X = df.drop(['ID', 'TYPE'], axis=1)
X
# Out:
#           RI   NA2O   MGO  AL2O3   SIO2   K2O   CAO   BAO  FE2O3
# 0    1.52101  13.64  4.49   1.10  71.78  0.06  8.75  0.00    0.0
# 1    1.51761  13.89  3.60   1.36  72.73  0.48  7.83  0.00    0.0
# 2    1.51618  13.53  3.55   1.54  72.99  0.39  7.78  0.00    0.0
# 3    1.51766  13.21  3.69   1.29  72.61  0.57  8.22  0.00    0.0
# 4    1.51742  13.27  3.62   1.24  73.08  0.55  8.07  0.00    0.0
# ..       ...    ...   ...    ...    ...   ...   ...   ...    ...
# 209  1.51623  14.14  0.00   2.88  72.61  0.08  9.18  1.06    0.0
# 210  1.51685  14.92  0.00   1.99  73.06  0.00  8.40  1.59    0.0
# 211  1.52065  14.36  0.00   2.02  73.42  0.00  8.44  1.64    0.0
# 212  1.51651  14.38  0.00   1.94  73.61  0.00  8.48  1.57    0.0
# 213  1.51711  14.23  0.00   2.08  73.36  0.00  8.62  1.67    0.0
#
# [214 rows x 9 columns]

# %%
y = df['TYPE']
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 209    7
# 210    7
# 211    7
# 212    7
# 213    7
# Name: TYPE, Length: 214, dtype: int64

# %%
importancias = mutual_info_classif(X, y)

# %%
importancias_df = pd.DataFrame({'feature': X.columns, 'importance': importancias})
importancias_df = importancias_df.sort_values('importance', ascending=False)
importancias_df
# Out:
#   feature  importance
# 2     MGO    0.411364
# 3   AL2O3    0.408421
# 5     K2O    0.356020
# 0      RI    0.353885
# 7     BAO    0.298036
# 1    NA2O    0.288375
# 6     CAO    0.242342
# 4    SIO2    0.085490
# 8   FE2O3    0.064123

# %%
k = 5
mejores = importancias_df['feature'].head(k).values
mejores
# Out:
# array(['MGO', 'AL2O3', 'K2O', 'RI', 'BAO'], dtype=object)

# %%
X_mejorado = X[mejores]
X_mejorado
# Out:
#       MGO  AL2O3   K2O       RI   BAO
# 0    4.49   1.10  0.06  1.52101  0.00
# 1    3.60   1.36  0.48  1.51761  0.00
# 2    3.55   1.54  0.39  1.51618  0.00
# 3    3.69   1.29  0.57  1.51766  0.00
# 4    3.62   1.24  0.55  1.51742  0.00
# ..    ...    ...   ...      ...   ...
# 209  0.00   2.88  0.08  1.51623  1.06
# 210  0.00   1.99  0.00  1.51685  1.59
# 211  0.00   2.02  0.00  1.52065  1.64
# 212  0.00   1.94  0.00  1.51651  1.57
# 213  0.00   2.08  0.00  1.51711  1.67
#
# [214 rows x 5 columns]

# %%
X_mejorado_train, X_mejorado_test, y_train, y_test = train_test_split(X_mejorado, y, test_size=0.2)

# %%
svm_model = SVC(kernel='linear')
svm_model.fit(X_mejorado_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = svm_model.predict(X_mejorado_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.5581395348837209

# %%
clf = tree.DecisionTreeClassifier()
clf.fit(X_mejorado_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_tree = clf.predict(X_mejorado_test)

# %%
accuracy_score(y_pred_tree, y_test)
# Out:
# 0.7441860465116279
