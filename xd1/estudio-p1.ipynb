# %%
import numpy as np
import pandas as pd

# %%
names = [
    'Class',
    'Alcohol',
 	'Malic acid',
 	'Ash',
	'Alcalinity of ash  ',
 	'Magnesium',
	'Total phenols',
 	'Flavanoids',
 	'Nonflavanoid phenols',
 	'Proanthocyanins',
	'Color intensity',
 	'Hue',
 	'OD280/OD315 of diluted wines',
 	'Proline'
]

# %%
path = "./wine_dataset/wine.data"
df = pd.read_csv(path, header=None, names=names)
df
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash    Magnesium  \
# 0        1    14.23        1.71  2.43                 15.6        127
# 1        1    13.20        1.78  2.14                 11.2        100
# 2        1    13.16        2.36  2.67                 18.6        101
# 3        1    14.37        1.95  2.50                 16.8        113
# 4        1    13.24        2.59  2.87                 21.0        118
# ..     ...      ...         ...   ...                  ...        ...
# 173      3    13.71        5.65  2.45                 20.5         95
# 174      3    13.40        3.91  2.48                 23.0        102
# 175      3    13.27        4.28  2.26                 20.0        120
# 176      3    13.17        2.59  2.37                 20.0        120
# 177      3    14.13        4.10  2.74                 24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# ...

# %%
df_by_class_mean = df.groupby('Class').apply('mean')
df_by_class_mean
# Out:
#          Alcohol  Malic acid       Ash  Alcalinity of ash     Magnesium  \
# Class
# 1      13.744746    2.010678  2.455593            17.037288  106.338983
# 2      12.278732    1.932676  2.244789            20.238028   94.549296
# 3      13.153750    3.333750  2.437083            21.416667   99.312500
#
#        Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# Class
# 1           2.840169    2.982373              0.290000         1.899322
# 2           2.258873    2.080845              0.363662         1.630282
# 3           1.678750    0.781458              0.447500         1.153542
#
#        Color intensity       Hue  OD280/OD315 of diluted wines      Proline
# Class
# 1             5.528305  1.062034                      3.157797  1115.711864
# 2             3.086620  1.056282                      2.785352   519.507042
# 3             7.396250  0.682708                      1.683542   629.895833

# %%
test1 = df.groupby('Class').transform('mean')
test1
# Out:
#        Alcohol  Malic acid       Ash  Alcalinity of ash     Magnesium  \
# 0    13.744746    2.010678  2.455593            17.037288  106.338983
# 1    13.744746    2.010678  2.455593            17.037288  106.338983
# 2    13.744746    2.010678  2.455593            17.037288  106.338983
# 3    13.744746    2.010678  2.455593            17.037288  106.338983
# 4    13.744746    2.010678  2.455593            17.037288  106.338983
# ..         ...         ...       ...                  ...         ...
# 173  13.153750    3.333750  2.437083            21.416667   99.312500
# 174  13.153750    3.333750  2.437083            21.416667   99.312500
# 175  13.153750    3.333750  2.437083            21.416667   99.312500
# 176  13.153750    3.333750  2.437083            21.416667   99.312500
# 177  13.153750    3.333750  2.437083            21.416667   99.312500
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# ...

# %%
added_column = df.copy()

added_column['Hue_classif'] = df['Hue'].map(lambda x: 'High' if x > 1 else 'Low')
added_column
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash    Magnesium  \
# 0        1    14.23        1.71  2.43                 15.6        127
# 1        1    13.20        1.78  2.14                 11.2        100
# 2        1    13.16        2.36  2.67                 18.6        101
# 3        1    14.37        1.95  2.50                 16.8        113
# 4        1    13.24        2.59  2.87                 21.0        118
# ..     ...      ...         ...   ...                  ...        ...
# 173      3    13.71        5.65  2.45                 20.5         95
# 174      3    13.40        3.91  2.48                 23.0        102
# 175      3    13.27        4.28  2.26                 20.0        120
# 176      3    13.17        2.59  2.37                 20.0        120
# 177      3    14.13        4.10  2.74                 24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# ...

# %%
dict = {
    'High': 1,
    'Low': 0
}
df['Hue_classif'] = added_column['Hue_classif'].map(dict)
df
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash    Magnesium  \
# 0        1    14.23        1.71  2.43                 15.6        127
# 1        1    13.20        1.78  2.14                 11.2        100
# 2        1    13.16        2.36  2.67                 18.6        101
# 3        1    14.37        1.95  2.50                 16.8        113
# 4        1    13.24        2.59  2.87                 21.0        118
# ..     ...      ...         ...   ...                  ...        ...
# 173      3    13.71        5.65  2.45                 20.5         95
# 174      3    13.40        3.91  2.48                 23.0        102
# 175      3    13.27        4.28  2.26                 20.0        120
# 176      3    13.17        2.59  2.37                 20.0        120
# 177      3    14.13        4.10  2.74                 24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# ...

# %%
df_copy = df.copy()
df_copy = df_copy.drop('Class', axis=1)
df_copy
# Out:
#      Alcohol  Malic acid   Ash  Alcalinity of ash    Magnesium  Total phenols  \
# 0      14.23        1.71  2.43                 15.6        127           2.80
# 1      13.20        1.78  2.14                 11.2        100           2.65
# 2      13.16        2.36  2.67                 18.6        101           2.80
# 3      14.37        1.95  2.50                 16.8        113           3.85
# 4      13.24        2.59  2.87                 21.0        118           2.80
# ..       ...         ...   ...                  ...        ...            ...
# 173    13.71        5.65  2.45                 20.5         95           1.68
# 174    13.40        3.91  2.48                 23.0        102           1.80
# 175    13.27        4.28  2.26                 20.0        120           1.59
# 176    13.17        2.59  2.37                 20.0        120           1.65
# 177    14.13        4.10  2.74                 24.5         96           2.05
#
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=178, step=1)

# %%
df_copy = df.copy()
df_copy = df_copy.drop('Class', axis=1)
df_copy
# Out:
#      Alcohol  Malic acid   Ash  Alcalinity of ash    Magnesium  Total phenols  \
# 0      14.23        1.71  2.43                 15.6        127           2.80
# 1      13.20        1.78  2.14                 11.2        100           2.65
# 2      13.16        2.36  2.67                 18.6        101           2.80
# 3      14.37        1.95  2.50                 16.8        113           3.85
# 4      13.24        2.59  2.87                 21.0        118           2.80
# ..       ...         ...   ...                  ...        ...            ...
# 173    13.71        5.65  2.45                 20.5         95           1.68
# 174    13.40        3.91  2.48                 23.0        102           1.80
# 175    13.27        4.28  2.26                 20.0        120           1.59
# 176    13.17        2.59  2.37                 20.0        120           1.65
# 177    14.13        4.10  2.74                 24.5         96           2.05
#
# ...

# %%
df_copy.mean()
# Out:
# Alcohol                          13.000618
# Malic acid                        2.336348
# Ash                               2.366517
# Alcalinity of ash                19.494944
# Magnesium                        99.741573
# Total phenols                     2.295112
# Flavanoids                        2.029270
# Nonflavanoid phenols              0.361854
# Proanthocyanins                   1.590899
# Color intensity                   5.058090
# Hue                               0.957449
# OD280/OD315 of diluted wines      2.611685
# Proline                         746.893258
# Hue_classif                       0.460674
# dtype: float64

# %%
df_copy - df_copy.mean()
# Out:
#       Alcohol  Malic acid       Ash  Alcalinity of ash    Magnesium  \
# 0    1.229382   -0.626348  0.063483            -3.894944  27.258427
# 1    0.199382   -0.556348 -0.226517            -8.294944   0.258427
# 2    0.159382    0.023652  0.303483            -0.894944   1.258427
# 3    1.369382   -0.386348  0.133483            -2.694944  13.258427
# 4    0.239382    0.253652  0.503483             1.505056  18.258427
# ..        ...         ...       ...                  ...        ...
# 173  0.709382    3.313652  0.083483             1.005056  -4.741573
# 174  0.399382    1.573652  0.113483             3.505056   2.258427
# 175  0.269382    1.943652 -0.106517             0.505056  20.258427
# 176  0.169382    0.253652  0.003483             0.505056  20.258427
# 177  1.129382    1.763652  0.373483             5.005056  -3.741573
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0         0.504888     1.03073             -0.081854         0.699101
# ...

# %%
abs(df_copy - df_copy.mean())
# Out:
#       Alcohol  Malic acid       Ash  Alcalinity of ash    Magnesium  \
# 0    1.229382    0.626348  0.063483             3.894944  27.258427
# 1    0.199382    0.556348  0.226517             8.294944   0.258427
# 2    0.159382    0.023652  0.303483             0.894944   1.258427
# 3    1.369382    0.386348  0.133483             2.694944  13.258427
# 4    0.239382    0.253652  0.503483             1.505056  18.258427
# ..        ...         ...       ...                  ...        ...
# 173  0.709382    3.313652  0.083483             1.005056   4.741573
# 174  0.399382    1.573652  0.113483             3.505056   2.258427
# 175  0.269382    1.943652  0.106517             0.505056  20.258427
# 176  0.169382    0.253652  0.003483             0.505056  20.258427
# 177  1.129382    1.763652  0.373483             5.005056   3.741573
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0         0.504888     1.03073              0.081854         0.699101
# ...

# %%
df_copy.std()
# Out:
# Alcohol                           0.811827
# Malic acid                        1.117146
# Ash                               0.274344
# Alcalinity of ash                 3.339564
# Magnesium                        14.282484
# Total phenols                     0.625851
# Flavanoids                        0.998859
# Nonflavanoid phenols              0.124453
# Proanthocyanins                   0.572359
# Color intensity                   2.318286
# Hue                               0.228572
# OD280/OD315 of diluted wines      0.709990
# Proline                         314.907474
# Hue_classif                       0.499857
# dtype: float64

# %%
n = 2
res = abs(df_copy - df_copy.mean() >= 2 * df_copy.std())
res
# Out:
#      Alcohol  Malic acid    Ash  Alcalinity of ash    Magnesium  \
# 0      False       False  False                False      False
# 1      False       False  False                False      False
# 2      False       False  False                False      False
# 3      False       False  False                False      False
# 4      False       False  False                False      False
# ..       ...         ...    ...                  ...        ...
# 173    False        True  False                False      False
# 174    False       False  False                False      False
# 175    False       False  False                False      False
# 176    False       False  False                False      False
# 177    False       False  False                False      False
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0            False       False                 False            False
# ...

# %%
res.sum()
# Out:
# Alcohol                         2
# Malic acid                      9
# Ash                             3
# Alcalinity of ash               5
# Magnesium                       6
# Total phenols                   2
# Flavanoids                      1
# Nonflavanoid phenols            5
# Proanthocyanins                 9
# Color intensity                 9
# Hue                             3
# OD280/OD315 of diluted wines    0
# Proline                         6
# Hue_classif                     0
# dtype: int64

# %%
columns = res.columns
columns
# Out:
# Index(['Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash  ', 'Magnesium',
#        'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue',
#        'OD280/OD315 of diluted wines', 'Proline', 'Hue_classif'],
#       dtype='object')

# %%
index_drop = res[res[columns].eq(True).any(axis=1)]
index_drop
# Out:
#      Alcohol  Malic acid    Ash  Alcalinity of ash    Magnesium  \
# 2      False       False  False                False      False
# 3      False       False  False                False      False
# 5      False       False  False                False      False
# 8       True       False  False                False      False
# 10     False       False  False                False      False
# 13      True       False  False                False      False
# 14     False       False  False                False      False
# 18     False       False  False                False      False
# 25     False       False   True                False      False
# 31     False       False  False                False      False
# 33     False       False  False                False       True
# 50     False       False  False                False      False
# 52     False       False  False                False      False
# 60     False       False  False                False      False
# ...
