# %%
import pandas as pd

# %%
attributes = [
	'Class',
    'Alcohol',
 	'Malic acid',
 	'Ash',
	'Alcalinity of ash  ',
 	'Magnesium',
	'Total phenols',
 	'Flavanoids',
 	'Nonflavanoid phenols',
 	'Proanthocyanins',
	'Color intensity',
 	'Hue',
 	'OD280/OD315 of diluted wines',
 	'Proline'
]

# %%
data_path = './wine_dataset/wine.data'

# %%
df = pd.read_csv(data_path, header=None, names=attributes)
df
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash    Magnesium  \
# 0        1    14.23        1.71  2.43                 15.6        127
# 1        1    13.20        1.78  2.14                 11.2        100
# 2        1    13.16        2.36  2.67                 18.6        101
# 3        1    14.37        1.95  2.50                 16.8        113
# 4        1    13.24        2.59  2.87                 21.0        118
# ..     ...      ...         ...   ...                  ...        ...
# 173      3    13.71        5.65  2.45                 20.5         95
# 174      3    13.40        3.91  2.48                 23.0        102
# 175      3    13.27        4.28  2.26                 20.0        120
# 176      3    13.17        2.59  2.37                 20.0        120
# 177      3    14.13        4.10  2.74                 24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# ...

# %% [markdown]
# ## groupby

# %%
analisis_por_clase = df.groupby('Class')['Alcohol'].mean()
analisis_por_clase
# Out:
# Class
# 1    13.744746
# 2    12.278732
# 3    13.153750
# Name: Alcohol, dtype: float64

# %% [markdown]
# ## apply

# %%
def get_color_intensity_level(value):
    if value > 7: return 'High'
    else: return 'Low'

color_int_lvl = df['Color intensity'].apply(get_color_intensity_level)
color_int_lvl[::15]
# Out:
# 0       Low
# 15     High
# 30      Low
# 45      Low
# 60      Low
# 75      Low
# 90      Low
# 105     Low
# 120     Low
# 135    High
# 150    High
# 165     Low
# Name: Color intensity, dtype: object

# %% [markdown]
# ## map

# %%
def get_alcohol_level(value):
    if value > 13.5:
        return 'High'
    elif 12.5 <= value <= 13.5:
        return 'Medium'
    else:
        return 'Low'

df['Alcohol level'] = df['Alcohol'].map(get_alcohol_level)
df[::20]
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash    Magnesium  \
# 0        1    14.23        1.71  2.43                 15.6        127
# 20       1    14.06        1.63  2.28                 16.0        126
# 40       1    13.56        1.71  2.31                 16.2        117
# 60       2    12.33        1.10  2.28                 16.0        101
# 80       2    12.00        0.92  2.00                 19.0         86
# 100      2    12.08        2.08  1.70                 17.5         97
# 120      2    11.45        2.40  2.42                 20.0         96
# 140      3    12.93        2.81  2.70                 21.0         96
# 160      3    12.36        3.83  2.38                 21.0         88
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# 20            3.00        3.17                  0.24             2.10
# ...

# %% [markdown]
# ## transform

# %%
def is_high_lvl(value):
    return value > value.quantile(0.75)
    
df['High fenol'] = df.groupby('Class')['Total phenols'].transform(
    is_high_lvl
)
df
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash    Magnesium  \
# 0        1    14.23        1.71  2.43                 15.6        127
# 1        1    13.20        1.78  2.14                 11.2        100
# 2        1    13.16        2.36  2.67                 18.6        101
# 3        1    14.37        1.95  2.50                 16.8        113
# 4        1    13.24        2.59  2.87                 21.0        118
# ..     ...      ...         ...   ...                  ...        ...
# 173      3    13.71        5.65  2.45                 20.5         95
# 174      3    13.40        3.91  2.48                 23.0        102
# 175      3    13.27        4.28  2.26                 20.0        120
# 176      3    13.17        2.59  2.37                 20.0        120
# 177      3    14.13        4.10  2.74                 24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# ...

# %%
is_high_lvl
)
df

# %% [markdown]
# ## aggregate

# %%
def mg_to_g(value):
    return value.sum() / 1000

analisis_por_clase = df.groupby('Class').agg({
    'Alcohol': ['mean', 'max'],
    'Proline': mg_to_g 
})
analisis_por_clase
# Out:
#          Alcohol        Proline
#             mean    max mg_to_g
# Class
# 1      13.744746  14.83  65.827
# 2      12.278732  13.86  36.885
# 3      13.153750  14.34  30.235

# %% [markdown]
# ## lambda

# %%
analisis_por_clase = df.groupby('Class').agg({
    'Alcohol': ['mean', 'max'],
    'Proline': lambda x: x.sum() / 1000 
})
analisis_por_clase
# Out:
#          Alcohol         Proline
#             mean    max <lambda>
# Class
# 1      13.744746  14.83   65.827
# 2      12.278732  13.86   36.885
# 3      13.153750  14.34   30.235
